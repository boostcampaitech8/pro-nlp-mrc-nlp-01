# %% [markdown]
# # Retrieval에 필요한 corpus 분석
#
# corpus 파일: wikipedia_documents.json

# %% [markdown]
# - 문서 개수 정확히 확인 (~57k개)
# - 문서 길이 분포
# - 문서 종류/주제 비율(title 기반)
# - 중복 문서 존재 여부
# - 문서들에서 가장 많이 등장하는 단어(빈도 분석)
# - 문서 embedding 예시 뽑아서 분포 확인
