# %% [markdown]
# # 질문 vs context 관계 분석

# %% [markdown]
# - question이 포함된 context 길이 분포
# - answer 위치가 context에서 앞쪽/중간/뒤쪽에 많이 등장하는지
#     - 예: answer_start histogram
# - 질문과 context 간의 lexical overlap(단어 겹침 비율)
# - 질문과 정답 간의 단어 유사도
